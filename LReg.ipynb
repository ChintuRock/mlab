# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
ft=pd.read_csv("Food-Truck(For Linear Regression Program).csv")

# %%
ft.head()
# Out:
#         a        b
# 0  5.5277   9.1302
# 1  8.5186  13.6620
# 2  7.0032  11.8540
# 3  5.8598   6.8233
# 4  8.3829  11.8860

# %%
X=ft['a']
Y=ft['b']

# %%
plt.scatter(X,Y)
plt.show()

# %%
mean_a=sum(X)/len(X)
mean_b=sum(Y)/len(Y)
print(mean_a)
print(mean_b)
# Out:
# 8.181151041666666
# 5.716709375

# %%
sm=0
den=0
for i in range(len(X)):
    sm+=(X[i]-mean_a)*(Y[i]-mean_b)
    den+=(X[i]-mean_a)**2
m=sm/den
print(m)
# Out:
# 1.2135472539083585

# %%
c=mean_b-m*mean_a

# %%
print(c)
# Out:
# -4.21150400542409

# %%
line=[m*i+c for i in X]
plt.plot(X,line,label="line fit",color="r")
plt.scatter(X,Y,label="points")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid(True)
plt.show()

# %%
print(line)
# Out:
# [2.4966211500051436, 6.1262196317196524, 4.287210123146926, 2.899640193028109, 5.961541269364287, 4.861460683696362, 6.1984256933271995, 3.659806192876305, 1.9224919441810986, 2.718700297470373, 12.977179298933901, 2.746975948486438, 5.992486724338952, 2.633751989696787, 2.316652092250534, 3.513209684604175, 2.0141147618511797, 3.591119418305091, 4.3692459175111305, 3.2992613037401313, 20.38709883129834, 2.4509917732581883, 3.465517277525577, 2.5417651078505337, 18.779148719869763, 11.355880167712332, 9.085333255649793, 11.77819461207244, 22.732885673103194, 2.1625315910041714, 3.7850442694796476, 7.011623708171192, 2.938473705153176, 5.753053851142833, 5.416051778732482, 5.61325320749259, 2.5920059641623405, 11.365588545743599, 3.498647117557274, 2.3500246417330137, 4.140734969600188, 9.99670724333497, 2.7951537744665993, 5.284139192232643, 4.3963080212732875, 1.941423281342069, 2.828769033399861, 9.986998865303704, 2.513489456834469, 4.9388849984957135, 2.2296407541453034, 4.797749452866172, 5.015217120766551, 3.4736480441267625, 3.505321627453771, 3.402534175047733, 2.63253844244288, 7.086863637913509, 7.260886314123968, 6.498535929218737, 2.0738212867434704, 21.611568010491872, 13.88005845584172, 18.79613838142448, 4.548122782737223, 5.854991820471134, 8.21036568558187, 2.462277762719536, 20.473260686325833, 8.089010960191029, 4.689258328366765, 3.0773035110002924, 4.557467096592318, 1.8888766852478378, 3.7346820584424503, 4.936943322889461, 1.9005267388853575, 8.256480481230383, 1.986931303363633, 2.7411509216676766, 2.084864566754036, 3.501438276241264, 7.643275053830492, 3.695848546317383, 6.124520665564181, 6.929102494905421, 3.0722066125338774, 2.4877622550516127, 1.9283169709998589, 2.7150596557086475, 5.055870953772479, 2.9128678580957104, 2.2268495954613146, 5.852928790139491, 12.042747913424463, 2.3864310593502633]

# %%
line=np.array(line)
nm=line.mean()

SSR=0
SST=0
for i in line:
    SSR+=(i-nm)**2
SSR
# Out:
# 2111.038639311627

# %%
for i in Y:
    SST+=(i-mean_b)**2
SST
# Out:
# 2775.2783647179613

# %%
r=SSR/SST
r
# Out:
# 0.23934165806601546

# %%
cost = (1 / (2 * len(X))) * sum((Y - line) ** 2)
print("Cost:", cost)
# Out:
# Cost: 3.459581903158004

# %%
SSE = sum((Y - line) ** 2)
print("Sum of Squared Errors (SSE):", SSE)
# Out:
# Sum of Squared Errors (SSE): 664.2397254063368
